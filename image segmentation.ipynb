# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../DataSets/sabrina1.jpg")
plt.imshow(img)

# %%
img_color=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
ret,thresh =cv2.threshold(gray,18,255,cv2.THRESH_BINARY)
ret1,thresh1 =cv2.threshold(gray,114,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
ret2,thresh2 =cv2.threshold(gray,18,255,cv2.THRESH_BINARY+cv2.THRESH_TRIANGLE)

print("otsu best value=",ret1 ,"/ triangle best value=",ret2)
# Out:
# otsu best value= 114.0 / triangle best value= 18.0

# %%
plt.figure('BINARY')
plt.imshow(thresh,cmap="gray")

# %%
plt.imshow(img_color)

# %% [markdown]
# # segmentation through knn

# %%
from sklearn.cluster import KMeans

# %%
img1 = plt.imread("../DataSets/dog.jpg")

# %%
plt.figure(figsize=(16,8))
plt.imshow(img1)

# %%
dg=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

# %%
ret2,thresh2 =cv2.threshold(dg,244,255,cv2.THRESH_BINARY+cv2.THRESH_TRIANGLE)
print(ret2)
# Out:
# 244.0

# %%
plt.imshow(thresh2,cmap="gray")
