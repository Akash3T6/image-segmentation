# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 10 --epochs 50 --data custom.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=drive/MyDrive/yolov5/data/hyps/hyp.scratch.yaml, epochs=50, batch_size=10, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=drive/MyDrive/yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 4 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-84-gdef7a0f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp15/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/test
# Out:
# python: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img=cv2.imread('/content/drive/MyDrive/yolov5/runs/detect/exp11/image_21.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=408x612 at 0x7F96E7B2E3D0>
